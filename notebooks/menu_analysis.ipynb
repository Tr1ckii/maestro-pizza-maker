# %%
cd ..
# Out:
# C:\Users\ricca\Documents\maestro-pizza-maker

# %%
from maestro_pizza_maker.pizza_menu import PizzaMenu
from maestro_pizza_maker.pizza import Pizza
from maestro_pizza_maker.ingredients import PizzaIngredients
from maestro_pizza_maker.pizza_sensitivities import *

from maestro_pizza_maker.pizza_optimizer import *
import numpy as np

# %%
# consider following menu
pizza_menu = PizzaMenu(
    pizzas=[
        Pizza(
            sauce=PizzaIngredients.CREAM_SAUCE,
            dough=PizzaIngredients.CLASSIC_DOUGH,
            cheese=[PizzaIngredients.MOZZARELA],
            fruits=[PizzaIngredients.PINEAPPLE],
            meat=[PizzaIngredients.BACON, PizzaIngredients.HAM],
            vegetables=[PizzaIngredients.ONIONS],
        ),
        Pizza(
            sauce=PizzaIngredients.TOMATO_SAUCE,
            dough=PizzaIngredients.THIN_DOUGH,
            cheese=[PizzaIngredients.CHEDDAR],
            fruits=[PizzaIngredients.APPLE],
            meat=[PizzaIngredients.SAUSAGE],
            vegetables=[PizzaIngredients.MUSHROOMS, PizzaIngredients.PEPPER],
        ),
        Pizza(
            sauce=PizzaIngredients.CREAM_SAUCE,
            dough=PizzaIngredients.WHOLEMEAL_DOUGH,
            cheese=[PizzaIngredients.MOZZARELA, PizzaIngredients.CHEDDAR],
            fruits=[PizzaIngredients.PINEAPPLE, PizzaIngredients.APPLE],
            meat=[
                PizzaIngredients.BACON,
                PizzaIngredients.HAM,
                PizzaIngredients.SAUSAGE,
            ],
            vegetables=[
                PizzaIngredients.MUSHROOMS,
                PizzaIngredients.ONIONS,
                PizzaIngredients.PEPPER,
            ],
        ),
        Pizza(
            sauce=PizzaIngredients.TOMATO_SAUCE,
            dough=PizzaIngredients.CLASSIC_DOUGH,
            cheese=[PizzaIngredients.MOZZARELA],
            fruits=[PizzaIngredients.PINEAPPLE],
            meat=[PizzaIngredients.BACON, PizzaIngredients.HAM],
            vegetables=[PizzaIngredients.ONIONS],
        ),
        Pizza(
            sauce=PizzaIngredients.CREAM_SAUCE,
            dough=PizzaIngredients.THIN_DOUGH,
            cheese=[PizzaIngredients.CHEDDAR],
            fruits=[PizzaIngredients.APPLE],
            meat=[PizzaIngredients.SAUSAGE],
            vegetables=[PizzaIngredients.MUSHROOMS, PizzaIngredients.PEPPER],
        ),
        Pizza(
            sauce=PizzaIngredients.TOMATO_SAUCE,
            dough=PizzaIngredients.WHOLEMEAL_DOUGH,
            cheese=[PizzaIngredients.MOZZARELA, PizzaIngredients.CHEDDAR],
            fruits=[PizzaIngredients.PINEAPPLE, PizzaIngredients.APPLE],
            meat=[
                PizzaIngredients.BACON,
                PizzaIngredients.HAM,
                PizzaIngredients.SAUSAGE,
            ],
            vegetables=[
                PizzaIngredients.MUSHROOMS,
                PizzaIngredients.ONIONS,
                PizzaIngredients.PEPPER,
            ],
        ),
        Pizza(
            sauce=PizzaIngredients.CREAM_SAUCE,
            dough=PizzaIngredients.CLASSIC_DOUGH,
            cheese=[PizzaIngredients.MOZZARELA],
            fruits=[PizzaIngredients.PINEAPPLE],
            meat=[PizzaIngredients.BACON, PizzaIngredients.HAM],
            vegetables=[PizzaIngredients.ONIONS],
        ),
        Pizza(
            sauce=PizzaIngredients.TOMATO_SAUCE,
            dough=PizzaIngredients.THIN_DOUGH,
            cheese=[PizzaIngredients.CHEDDAR],
            fruits=[PizzaIngredients.APPLE],
            meat=[PizzaIngredients.SAUSAGE],
            vegetables=[PizzaIngredients.MUSHROOMS, PizzaIngredients.PEPPER],
        ),
        Pizza(
            sauce=PizzaIngredients.CREAM_SAUCE,
            dough=PizzaIngredients.WHOLEMEAL_DOUGH,
            cheese=[PizzaIngredients.MOZZARELA, PizzaIngredients.CHEDDAR],
            fruits=[PizzaIngredients.PINEAPPLE, PizzaIngredients.APPLE],
            meat=[
                PizzaIngredients.BACON,
                PizzaIngredients.HAM,
                PizzaIngredients.SAUSAGE,
            ],
            vegetables=[
                PizzaIngredients.MUSHROOMS,
                PizzaIngredients.ONIONS,
                PizzaIngredients.PEPPER,
            ],
        ),
        Pizza(
            sauce=PizzaIngredients.TOMATO_SAUCE,
            dough=PizzaIngredients.CLASSIC_DOUGH,
            cheese=[PizzaIngredients.MOZZARELA],
            fruits=[PizzaIngredients.PINEAPPLE],
            meat=[PizzaIngredients.BACON, PizzaIngredients.HAM],
            vegetables=[PizzaIngredients.ONIONS],
        ),
    ]
)

# %%
Pizza_1 =   Pizza(
            sauce=PizzaIngredients.CREAM_SAUCE,
            dough=PizzaIngredients.CLASSIC_DOUGH,
            cheese=[PizzaIngredients.MOZZARELA],
            fruits=[PizzaIngredients.PINEAPPLE],
            meat=[PizzaIngredients.BACON, PizzaIngredients.HAM],
            vegetables=[PizzaIngredients.ONIONS],
        )
Pizza_2 =  Pizza(
            sauce=PizzaIngredients.TOMATO_SAUCE,
            dough=PizzaIngredients.CLASSIC_DOUGH,
            cheese=[PizzaIngredients.MOZZARELA],
            fruits=[PizzaIngredients.PINEAPPLE],
            meat=[PizzaIngredients.BACON, PizzaIngredients.HAM],
            vegetables=[PizzaIngredients.ONIONS],
        )

# %%
# create a dataframe with the menu using the to_dataframe method you have implemented in the PizzaMenu class
# and display it

pizza_menu.add_pizza(Pizza_2)

df_pizza_menu = pizza_menu.to_dataframe(sort_by="price",descendent = True)

df_pizza_menu
# Out:
#                                                  name  price  protein  \
# 1   Pizza THIN_DOUGH TOMATO_SAUCE CHEDDAR APPLE SA...    6.5     45.5
# 7   Pizza THIN_DOUGH TOMATO_SAUCE CHEDDAR APPLE SA...    6.5     45.5
# 4   Pizza THIN_DOUGH CREAM_SAUCE CHEDDAR APPLE SAU...    6.6     45.6
# 3   Pizza CLASSIC_DOUGH TOMATO_SAUCE MOZZARELA PIN...    7.5     60.5
# 9   Pizza CLASSIC_DOUGH TOMATO_SAUCE MOZZARELA PIN...    7.5     60.5
# 10  Pizza CLASSIC_DOUGH TOMATO_SAUCE MOZZARELA PIN...    7.5     60.5
# 11  Pizza CLASSIC_DOUGH TOMATO_SAUCE MOZZARELA PIN...    7.5     60.5
# 12  Pizza CLASSIC_DOUGH TOMATO_SAUCE MOZZARELA PIN...    7.5     60.5
# 13  Pizza CLASSIC_DOUGH TOMATO_SAUCE MOZZARELA PIN...    7.5     60.5
# 14  Pizza CLASSIC_DOUGH TOMATO_SAUCE MOZZARELA PIN...    7.5     60.5
# 0   Pizza CLASSIC_DOUGH CREAM_SAUCE MOZZARELA PINE...    7.6     60.6
# 6   Pizza CLASSIC_DOUGH CREAM_SAUCE MOZZARELA PINE...    7.6     60.6
# 5   Pizza WHOLEMEAL_DOUGH TOMATO_SAUCE MOZZARELA C...   12.5     95.5
# 2   Pizza WHOLEMEAL_DOUGH CREAM_SAUCE MOZZARELA CH...   12.6     95.6
# 8   Pizza WHOLEMEAL_DOUGH CREAM_SAUCE MOZZARELA CH...   12.6     95.6
#
#     average_fat  carbohydrates  calories  \
# 1     30.975220           28.0    1070.0
# 7     30.975220           28.0    1070.0
# 4     28.433676           29.0    1080.0
# 3     29.381972           23.0    1820.0
# 9     29.381972           23.0    1820.0
# 10    29.381972           23.0    1820.0
# 11    29.381972           23.0    1820.0
# 12    29.381972           23.0    1820.0
# 13    29.381972           23.0    1820.0
# 14    29.381972           23.0    1820.0
# 0     26.840428           24.0    1830.0
# 6     26.840428           24.0    1830.0
# 5     28.972889           38.0    2770.0
# 2     27.490322           39.0    2780.0
# 8     27.490322           39.0    2780.0
#
#                                           ingredients
# 1   [PizzaIngredients.THIN_DOUGH, PizzaIngredients...
# 7   [PizzaIngredients.THIN_DOUGH, PizzaIngredients...
# 4   [PizzaIngredients.THIN_DOUGH, PizzaIngredients...
# 3   [PizzaIngredients.CLASSIC_DOUGH, PizzaIngredie...
# 9   [PizzaIngredients.CLASSIC_DOUGH, PizzaIngredie...
# 10  [PizzaIngredients.CLASSIC_DOUGH, PizzaIngredie...
# 11  [PizzaIngredients.CLASSIC_DOUGH, PizzaIngredie...
# 12  [PizzaIngredients.CLASSIC_DOUGH, PizzaIngredie...
# 13  [PizzaIngredients.CLASSIC_DOUGH, PizzaIngredie...
# 14  [PizzaIngredients.CLASSIC_DOUGH, PizzaIngredie...
# 0   [PizzaIngredients.CLASSIC_DOUGH, PizzaIngredie...
# 6   [PizzaIngredients.CLASSIC_DOUGH, PizzaIngredie...
# 5   [PizzaIngredients.WHOLEMEAL_DOUGH, PizzaIngred...
# 2   [PizzaIngredients.WHOLEMEAL_DOUGH, PizzaIngred...
# 8   [PizzaIngredients.WHOLEMEAL_DOUGH, PizzaIngred...

# %%
pizza_menu.to_dataframe(sort_by="price",descendent = True)

# %%
# compute basic descriptive statistics for the menu.
# pay a special attention to the price column, as it is the most important one

df = pizza_menu.to_dataframe(sort_by="price",descendent = True)
mean = df[["price","protein","average_fat","carbohydrates","calories"]].mean()
std_dev = df[["price","protein","average_fat","carbohydrates","calories"]].std()

# Following steps are optional, but recommended:
# 1. Create a boxplot for the price column
df.boxplot(column=["price"])
# 2. Create a histogram for the price column
df.hist(column=["price"])

# 3. Create a scatter plot for the price column and any other column of your choice
df.plot.scatter(x=df["price"],y=df["average_fat"])

# %%
# Try to answer follwing question:
# 1. How much will price change on average if we increase the amount of protein in the pizza by 1 unit?
print(menu_sensitivity_protein(pizza_menu))
# 2. How much will price change on average if we increase the amount of average_fat in the pizza by 1 unit?
print(menu_sensitivity_carbs(pizza_menu))

# 3. How much will price change on average if we increase the amount of carbohydrates in the pizza by 1 unit?

print(menu_sensitivity_fat(pizza_menu))
# Hint: use functions that you have implemented in the pizza_sensitivities.py
# Out:
# 1.2
# 1.2000000000000002
# 1.2000000000000002

# %%
Pizza_1.taste

# %%
# Compute Taste at Risk (TaR) for each pizza in the menu and for the whole menu and briefly comment on the results
# Use quantile = 0.1

from maestro_pizza_maker.taste_at_risk import *

quantile = 0.10

lst = []

for pizza in pizza_menu.pizzas: lst.append(taste_at_risk_pizza(pizza,quantile))
    
sum_of_var = np.sum(np.array(lst))
    
menu_var = taste_at_risk_menu(pizza_menu,quantile)

print(sum_of_var)
print(menu_var)
print(taste_at_risk_pizza(pizza,quantile))

# Answer following question:
# 1. Does the sum of TaR for each pizza in the menu equal to the TaR of the whole menu and why?

# Hint: use functions that you have implemented in the taste_at_risk.py
# Out:
# 363916.610125033
# 704825.6666418843
# 28251.841936141558

# %%
# Compute Conditional Taste at Risk (CTaR) for each pizza in the menu and for the whole menu and briefly comment on the results
for pizza in pizza_menu.pizzas:
    print(conditional_taste_at_risk_pizza(pizza,0.05))
# Hint: use functions that you have implemented in the taste_at_risk.py

print(conditional_taste_at_risk_menu(pizza_menu,0.05))
# Out:
# 28247.455375484846
# 22991.202980281338
# 51228.78602559586
# 28251.013536739454
# 22987.64481902673
# 51232.344186850474
# 28247.455375484846
# 22991.202980281338
# 51228.78602559586
# 28251.013536739454
# 28251.013536739454
# 28251.013536739454
# 761330.571309376

# %%
# Define constraints_values and constraints_ingredients and find the optimal pizza using the func maximize_taste_penalty_price, that you have implemented in the pizza_optimizer.py
# Use lambda_param = 0.5
class PizzaConstraintsValues:
    price: ValueBounds = ValueBounds()
    protein: ValueBounds = ValueBounds()
    fat: ValueBounds = ValueBounds()
    carbohydrates: ValueBounds = ValueBounds()
    calories: ValueBounds = ValueBounds()


@dataclass
class PizzaConstraintsIngredients:
    cheese: int = 0
    fruits: int = 0
    meat: int = 0
    vegetables: int = 0
    dough: int = 1
    sauce: int = 1

best_pizza = maximize_taste_penalty_price(PizzaConstraintsValues,
    PizzaConstraintsIngredients)

pizza_menu.add_pizza(best_pizza)

# Add this pizza to the menu using the add_pizza method of the PizzaMenu class

# %%
# Compute the new TaR and CTaR for the whole new menu with added pizza
Pizza_3 =  Pizza(
            sauce=PizzaIngredients.TOMATO_SAUCE,
            dough=PizzaIngredients.CLASSIC_DOUGH,
            cheese=[PizzaIngredients.MOZZARELA],
            fruits=[PizzaIngredients.APPLE],
            meat=[PizzaIngredients.BACON, PizzaIngredients.BACON],
            vegetables=[PizzaIngredients.ONIONS],
        )

new_pizza_menu  = PizzaMenu(
    pizzas=[
        Pizza(
            sauce=PizzaIngredients.CREAM_SAUCE,
            dough=PizzaIngredients.CLASSIC_DOUGH,
            cheese=[PizzaIngredients.MOZZARELA],
            fruits=[PizzaIngredients.PINEAPPLE],
            meat=[PizzaIngredients.BACON, PizzaIngredients.HAM],
            vegetables=[PizzaIngredients.ONIONS],
        ),
        Pizza(
            sauce=PizzaIngredients.TOMATO_SAUCE,
            dough=PizzaIngredients.THIN_DOUGH,
            cheese=[PizzaIngredients.CHEDDAR],
            fruits=[PizzaIngredients.APPLE],
            meat=[PizzaIngredients.SAUSAGE],
            vegetables=[PizzaIngredients.MUSHROOMS, PizzaIngredients.PEPPER],
        ),
        Pizza(
            sauce=PizzaIngredients.CREAM_SAUCE,
            dough=PizzaIngredients.WHOLEMEAL_DOUGH,
            cheese=[PizzaIngredients.MOZZARELA, PizzaIngredients.CHEDDAR],
            fruits=[PizzaIngredients.PINEAPPLE, PizzaIngredients.APPLE],
            meat=[
                PizzaIngredients.BACON,
                PizzaIngredients.HAM,
                PizzaIngredients.SAUSAGE,
            ],
            vegetables=[
                PizzaIngredients.MUSHROOMS,
                PizzaIngredients.ONIONS,
                PizzaIngredients.PEPPER,
            ]
        )
    ]
)


print(conditional_taste_at_risk_menu(new_pizza_menu,0.05))
print(taste_at_risk_menu(new_pizza_menu,.05))
      
print(conditional_taste_at_risk_menu(pizza_menu,0.05))
print(taste_at_risk_menu(pizza_menu,.05))
# Out:
# 181944.64736108217
# 181944.37885041692
# 386889.89686353446
# 386889.54158970737

# %%
# Compare old and new TaR and CTaR and briefly comment on the results.

'''Unfortunately had some issues with the implementation of the maximize_taste_penalty_price function, but comparing
    the two menus above we can see that the taste at risk and conditional taste at risk straightforwardly increase as a
    function of the number of pizzas in the menu, hence an increase of the taste in the menu.
'''
# Out:
# 'Unfortunately had some issues with the implementation of the maximize_taste_penalty_price function, but comparing\n    the two menus above we can see that the taste at risk and conditional taste at risk straightforwardly increase as a\n    function of the number of pizzas in the menu, hence an increase of the taste in the menu.\n'

# %%
# Out:
# True
